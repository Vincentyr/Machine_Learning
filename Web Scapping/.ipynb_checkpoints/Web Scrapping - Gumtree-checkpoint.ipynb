# %%
import requests
import pandas as pd
import seaborn as sns
import re as re
from bs4 import BeautifulSoup

# %%
req = requests.get("https://www.gumtree.sg/s-property-for-rent/v1c12p1")

# %%
contents = req.content
soup = BeautifulSoup(contents, "html.parser")
all_houses = soup.find_all("div", class_ = "tileV1")

# %%
l =[]
for house_price in all_houses:
    dataframe ={}
    a = house_price.find_all("div", class_ = "info")
    b = house_price.find_all("div", class_ = "category-location")
    locations = b[0].find_all("span")[0].text.split(",")[1][1:]
    dataframe['Property Details'] = house_price.a.text
    dataframe['Price'] = a[0].find_all("span")[0].text.replace("\n", "")
    dataframe['Location'] = locations.split("/")
    l.append(dataframe)
print(l)
# Out:
# [{'Property Details': 'River valley home ready for rent ', 'Price': '                    $8,000                                    ', 'Location': ['Orchard ', ' River Valley']}, {'Property Details': 'Costa Del Sol / 4BR / 1755sf for rent', 'Price': '                    $6,700                                    ', 'Location': ['Bedok ', ' Upper East Coast']}, {'Property Details': 'Breeze high floor flat overlooking the Causeway', 'Price': '                    $1,150                                    ', 'Location': ['Admiralty ', ' Woodlands']}, {'Property Details': 'Apartment / Condo For RENT: The Peak @ Cairnhill II', 'Price': '                    $4,200                                    ', 'Location': ['Orchard ', ' River Valley']}, {'Property Details': "Cosy 3 'Ng' unit near Hougang Mrt", 'Price': '                    $2,300                                    ', 'Location': ['Hougang ', ' Punggol ', ' Sengkang']}, {'Property Details': 'The MEZZO 2BDRM - UNBLOCK VIEW', 'Price': '                    $3,300                                    ', 'Location': ['Balestier ', ' Toa Payoh']}, {'Property Details': 'Unique Loft Studio Room at Bendemeer/Lavender/Farrer Park MRT for Single Professional', 'Price': '                    $1,680                                    ', 'Location': ['Farrer Park ', ' Serangoon Rd']}, {'Property Details': "All Females Apt.3-4mins'walk to FarrerPark/Little IndiaMRT.Near NAFA/LASELLE/SMU", 'Price': '                    $900                                    ', 'Location': ['Beach Road ', ' Bugis ', ' Rochor']}, {'Property Details': 'Bugis One and Two Bedroom Shophouse Loft Apartment for lease', 'Price': '                    $3,300                                    ', 'Location': ['Beach Road ', ' Bugis ', ' Rochor']}, {'Property Details': 'Be the 1st to move in  this  convenient condo ', 'Price': '                    $2,600                                    ', 'Location': ['Balestier ', ' Toa Payoh']}, {'Property Details': 'Nice Studio Room at Bendemeer/Lavender/Farrer Park MRT for Single Professional', 'Price': '                    $1,380                                    ', 'Location': ['Farrer Park ', ' Serangoon Rd']}, {'Property Details': 'Common Room available for Rent in blk 165- simei road - Near Simei/Tampinese MRT ', 'Price': 'Contact for Price', 'Location': ['Pasir Ris ', ' Tampines']}, {'Property Details': '2BHK HDB for Rent @ 523 AMK Avenue 5', 'Price': '                    $2,000                                    ', 'Location': ['Ang Mo Kio ', ' Bishan ', ' Thomson']}, {'Property Details': 'Common room - Yishun.. MRT INDIAN OWNER', 'Price': '                    $800                                    ', 'Location': ['Sembawang ', ' Yishun']}, {'Property Details': 'Near Sengkang MRT! - 3+1 / 186D Rivervale  Drive / HDB Whole Unit for rent $2600', 'Price': '                    $2,600                                    ', 'Location': ['Hougang ', ' Punggol ', ' Sengkang']}, {'Property Details': 'Nice New 1,2,3 bedder for Rent', 'Price': 'Contact for Price', 'Location': ['Eunos ', ' Geylang ', ' Paya Lebar']}, {'Property Details': 'Spacious and Tastefully Renovated 3 Br for Rent', 'Price': '                    $9,800                                    ', 'Location': ['Orchard ', ' River Valley']}, {'Property Details': 'Single room for 1 person ', 'Price': '                    $500                                    ', 'Location': ['Chinatown ', ' Tanjong Pagar']}, {'Property Details': 'Common room for rent ', 'Price': '                    $450                                    ', 'Location': ['Pasir Ris ', ' Tampines']}, {'Property Details': '2+1 Near Bedok MRT! - (202 Bedok North Street 1) HDB Whole Unit for rent $2200', 'Price': '                    $2,200                                    ', 'Location': ['Bedok ', ' Upper East Coast']}, {'Property Details': 'I bedroom Condo for rent ', 'Price': '                    $2,200                                    ', 'Location': ['Houg ...

# %%
df = pd.DataFrame(l)
print(df)
# Out:
#                                      Property Details  \
# 0                   River valley home ready for rent
# 1               Costa Del Sol / 4BR / 1755sf for rent
# 2     Breeze high floor flat overlooking the Causeway
# 3   Apartment / Condo For RENT: The Peak @ Cairnhi...
# 4                   Cosy 3 'Ng' unit near Hougang Mrt
# 5                      The MEZZO 2BDRM - UNBLOCK VIEW
# 6   Unique Loft Studio Room at Bendemeer/Lavender/...
# 7   All Females Apt.3-4mins'walk to FarrerPark/Lit...
# 8   Bugis One and Two Bedroom Shophouse Loft Apart...
# 9      Be the 1st to move in  this  convenient condo
# 10  Nice Studio Room at Bendemeer/Lavender/Farrer ...
# 11  Common Room available for Rent in blk 165- sim...
# 12               2BHK HDB for Rent @ 523 AMK Avenue 5
# 13            Common room - Yishun.. MRT INDIAN OWNER
# 14  Near Sengkang MRT! - 3+1 / 186D Rivervale  Dri...
# 15                     Nice New 1,2,3 bedder for Rent
# 16    Spacious and Tastefully Renovated 3 Br for Rent
# 17                          Single room for 1 person
# 18                              Common room for rent
# 19  2+1 Near Bedok MRT! - (202 Bedok North Street ...
# 20                          I bedroom Condo for rent
#
#                                                 Price  \
# 0                       $8,000                    ...
# 1                       $6,700                    ...
# 2                       $1,150                    ...
# 3                       $4,200                    ...
# 4                       $2,300                    ...
# 5                       $3,300                    ...
# 6                       $1,680                    ...
# 7                       $900                      ...
# 8                       $3,300                    ...
# 9                       $2,600                    ...
# 10                      $1,380                    ...
# 11                                  Contact for Price
# 12                      $2,000                    ...
# 13                      $800                      ...
# 14                      $2,600                    ...
# 15                                  Contact for Price
# 16                      $9,800                    ...
# 17                      $500                      ...
# 18                      $450                      ...
# 19                      $2,200                    ...
# 20                      $2,200                    ...
#
#                              Location
# 0           [Orchard ,  River Valley]
# 1         [Bedok ,  Upper East Coast]
# 2            [Admiralty ,  Woodlands]
# 3           [Orchard ,  River Valley]
# 4    [Hougang ,  Punggol ,  Sengkang]
# 5            [Balestier ,  Toa Payoh]
# 6       [Farrer Park ,  Serangoon Rd]
# 7     [Beach Road ,  Bugis ,  Rochor]
# 8     [Beach Road ,  Bugis ,  Rochor]
# 9            [Balestier ,  Toa Payoh]
# 10      [Farrer Park ,  Serangoon Rd]
# 11            [Pasir Ris ,  Tampines]
# 12  [Ang Mo Kio ,  Bishan ,  Thomson]
# 13              [Sembawang ,  Yishun]
# 14   [Hougang ,  Punggol ,  Sengkang]
# 15   [Eunos ,  Geylang ,  Paya Lebar]
# 16          [Orchard ,  River Valley]
# 17       [Chinatown ,  Tanjong Pagar]
# 18            [Pasir Ris ,  Tampines]
# 19        [Bedok ,  Upper East Coast]
# 20   [Hougang ,  Punggol ,  Sengkang]

# %%
def find_number(text):
    num = re.findall(r'[0-9]+',text)
    return "".join(num)
df['Price'] = df['Price'].apply(lambda x: find_number(x))
# Out:
#                                      Property Details Price  \
# 0                   River valley home ready for rent   8000
# 1               Costa Del Sol / 4BR / 1755sf for rent  6700
# 2     Breeze high floor flat overlooking the Causeway  1150
# 3   Apartment / Condo For RENT: The Peak @ Cairnhi...  4200
# 4                   Cosy 3 'Ng' unit near Hougang Mrt  2300
# 5                      The MEZZO 2BDRM - UNBLOCK VIEW  3300
# 6   Unique Loft Studio Room at Bendemeer/Lavender/...  1680
# 7   All Females Apt.3-4mins'walk to FarrerPark/Lit...   900
# 8   Bugis One and Two Bedroom Shophouse Loft Apart...  3300
# 9      Be the 1st to move in  this  convenient condo   2600
# 10  Nice Studio Room at Bendemeer/Lavender/Farrer ...  1380
# 11  Common Room available for Rent in blk 165- sim...
# 12               2BHK HDB for Rent @ 523 AMK Avenue 5  2000
# 13            Common room - Yishun.. MRT INDIAN OWNER   800
# 14  Near Sengkang MRT! - 3+1 / 186D Rivervale  Dri...  2600
# 15                     Nice New 1,2,3 bedder for Rent
# 16    Spacious and Tastefully Renovated 3 Br for Rent  9800
# 17                          Single room for 1 person    500
# 18                              Common room for rent    450
# 19  2+1 Near Bedok MRT! - (202 Bedok North Street ...  2200
# 20                          I bedroom Condo for rent   2200
#
#                              Location
# 0           [Orchard ,  River Valley]
# 1         [Bedok ,  Upper East Coast]
# 2            [Admiralty ,  Woodlands]
# 3           [Orchard ,  River Valley]
# 4    [Hougang ,  Punggol ,  Sengkang]
# 5            [Balestier ,  Toa Payoh]
# 6       [Farrer Park ,  Serangoon Rd]
# 7     [Beach Road ,  Bugis ,  Rochor]
# 8     [Beach Road ,  Bugis ,  Rochor]
# 9            [Balestier ,  Toa Payoh]
# 10      [Farrer Park ,  Serangoon Rd]
# 11            [Pasir Ris ,  Tampines]
# 12  [Ang Mo Kio ,  Bishan ,  Thomson]
# 13              [Sembawang ,  Yishun]
# 14   [Hougang ,  Punggol ,  Sengkang]
# 15   [Eunos ,  Geylang ,  Paya Lebar]
# 16          [Orchard ,  River Valley]
# 17       [Chinatown ,  Tanjong Pagar]
# 18            [Pasir Ris ,  Tampines]
# 19        [Bedok ,  Upper East Coast]
# 20   [Hougang ,  Punggol ,  Sengkang]
